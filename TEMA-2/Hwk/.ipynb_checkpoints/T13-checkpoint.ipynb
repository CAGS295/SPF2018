# %% [markdown]
# # Tarea
#
# Aproxime el valor de la siguiente integral usando el método monte carlo crudo y método de reducción de varianza de muestreo estratíficado
#
# $$I=\int_{0}^{1}x^2\text{d}x=\left.\frac{x^3}{3}\right|_{x=0}^{x=1}=\frac{1}{3}\approx 0.33333$$
#
# Pasos
# 1. Cree una función que realice el método de muestreo estratíficado, recibiendo como único parámetro de entrada la cantidad de estratos y retornando las variables estratíficadas correspondientes.

# %%
import numpy as np
import numpy.random as r

# %%
def x2(m):
    container = np.zeros(m)
    final = []
    Ns = 10**np.arange(1,7+1)/m
    f = lambda x:x**2        
    for n in Ns: 
        for j in range(m):
            container[j]=sum(f((r.rand(int(n))+j)/m))/m/n
        final.append(sum(container))
    return final

# %%
x2(5)
# Out:
# [0.35143494917305107,
#  0.33928152234918385,
#  0.33199732807057813,
#  0.33322896601118207,
#  0.333419114925226,
#  0.33335015409687063,
#  0.3333464922112732]

# %% [markdown]
# 2. Reporte los resultados de la aproximación de la integral usando montecarlo crudo y muestreo estratíficado, en un Dataframe con la información mostrada en la siguiente imagen:
# ![image.png](attachment:image.png)

# %%
import pandas as pd
ix = 10**np.arange(1,7+1)
frame = pd.DataFrame(index=ix)
frame.index.name='términos'
simple = x2(1)
estrat = x2(5)
frame.loc[ix,'Montecarlo simple'] = simple
frame.loc[ix,'Error S'] = np.abs((1/3-np.array(simple))*100)
frame.loc[ix,'Montecarlo estratificado'] = x2(1)
frame.loc[ix,'Error E'] = np.abs((1/3-np.array(estrat))*100)

# %%
frame
# Out:
#           Montecarlo simple   Error S  Montecarlo estratificado   Error E
# términos
# 10                 0.396173  6.283981                  0.281255  1.640904
# 100                0.337520  0.418673                  0.334613  0.662912
# 1000               0.357959  2.462566                  0.331423  0.152164
# 10000              0.337017  0.368350                  0.332663  0.070955
# 100000             0.334207  0.087393                  0.332459  0.030490
# 1000000            0.333085  0.024827                  0.333419  0.011749
# 10000000           0.333305  0.002852                  0.333293  0.000452

# %% [markdown]
# Creo que asignar pesos iguales para cada estrato no es tan efectivo como si arbitrariamente se escogieran pesos distintos para cada estrato. La forma en que asignan los pesos puede cambiar la velocidad de convergencia.
